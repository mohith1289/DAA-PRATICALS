# %% [markdown]
# <a href="https://colab.research.google.com/github/mohith1289/DAA-PRATICALS/blob/main/DAA_Pratical_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0/1 Knapsack Problem using Dynamic Programming

weights = [2, 4, 6, 5]
profits = [3, 5, 6, 7]
capacity = 5

n = len(weights)

# Create DP table
dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

# Fill DP table
for i in range(1, n + 1):
    for w in range(1, capacity + 1):
        if weights[i - 1] <= w:
            dp[i][w] = max(
                profits[i - 1] + dp[i - 1][w - weights[i - 1]],
                dp[i - 1][w]
            )
        else:
            dp[i][w] = dp[i - 1][w]

print("Maximum Profit =", dp[n][capacity])
# Out:
# Maximum Profit = 7
