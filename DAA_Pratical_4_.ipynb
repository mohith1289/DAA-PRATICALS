# %% [markdown]
# <a href="https://colab.research.google.com/github/mohith1289/DAA-PRATICALS/blob/main/DAA_Pratical_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Iterative Method to calculate Factorial
def factorial_iterative(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result


# 2. Recursive Method to calculate Factorial
def factorial_recursive(n):
    # Base Case
    if n <= 1:
        return 1

    # Recursive Case
    return n * factorial_recursive(n - 1)


# Main Program
num = int(input("Enter a positive integer: "))

if num < 0:
    print("Factorial of a negative number is not defined.")
else:
    # Run Iterative Method
    iterative_result = factorial_iterative(num)
    print("\n--- Iterative Method ---")
    print("Factorial of", num, "is:", iterative_result)

    # Run Recursive Method
    recursive_result = factorial_recursive(num)
    print("\n--- Recursive Method ---")
    print("Factorial of", num, "is:", recursive_result)
# Out:
# Enter a positive integer: 5
#
# --- Iterative Method ---
# Factorial of 5 is: 120
#
# --- Recursive Method ---
# Factorial of 5 is: 120
